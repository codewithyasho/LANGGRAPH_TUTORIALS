# %% [markdown]
# ## **Parallelization Workflow**

# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from langchain_ollama import ChatOllama

# %%
# Graph state
class AgentState(TypedDict):
    topic: str
    joke: str
    story: str
    poem: str
    combined_output: str

# %%
llm = ChatOllama(model="deepseek-v3.1:671b-cloud")

# %%
# Nodes
def call_llm_1(state: AgentState):
    """First LLM call to generate initial joke"""

    msg = llm.invoke(f"Write a joke about {state['topic']}")
    return {"joke": msg.content}


def call_llm_2(state: AgentState):
    """Second LLM call to generate story"""

    msg = llm.invoke(f"Write a story about {state['topic']}")
    return {"story": msg.content}


def call_llm_3(state: AgentState):
    """Third LLM call to generate poem"""

    msg = llm.invoke(f"Write a poem about {state['topic']}")
    return {"poem": msg.content}

# %%
def aggregator(state: AgentState):
    """Combine the joke, story and poem into a single output"""

    combined = f"Here's a story, joke, and poem about {state['topic']}!\n\n"
    combined += f"STORY:\n{state['story']}\n\n"
    combined += f"JOKE:\n{state['joke']}\n\n"
    combined += f"POEM:\n{state['poem']}"
    return {"combined_output": combined}

# %%
graph = StateGraph(AgentState)

# Add nodes
graph.add_node("call_llm_1", call_llm_1)
graph.add_node("call_llm_2", call_llm_2)
graph.add_node("call_llm_3", call_llm_3)
graph.add_node("aggregator", aggregator)

# Add edges to connect nodes
graph.add_edge(START, "call_llm_1")
graph.add_edge(START, "call_llm_2")
graph.add_edge(START, "call_llm_3")

graph.add_edge("call_llm_1", "aggregator")
graph.add_edge("call_llm_2", "aggregator")
graph.add_edge("call_llm_3", "aggregator")

graph.add_edge("aggregator", END)

# %%
app = graph.compile()
app

# %%
# Invoke
state = app.invoke({"topic": "cats"})

# %%
print(state["combined_output"])
# Out:
# Here's a story, joke, and poem about cats!
#
# STORY:
# The world, for Barnaby, was a symphony of scents and a map of sunbeams. He was a creature of immense dignity, a ginger tabby of considerable girth, whose domain was the comfortable, slightly dusty house on Willow Lane. His days followed a sacred rhythm: a sunbeam on the Persian rug from nine to eleven, a strategic nap atop the linen cupboard from eleven to one, and a vigilant patrol of the backyard bird feeder in the afternoon.
#
# Humans, he tolerated. They were useful for can-opening and chin-scratches, but their movements were erratic and their conversations lacked nuance. True conversation, Barnaby knew, happened in the silent blink of an eye, the slow twitch of a tail tip, the subtle arch of a back.
#
# His peace was shattered on a Tuesday.
#
# The humans brought it in—a small, squeaking, grey-and-white scrap of chaos bundled in a blanket. They called it "Pip." Barnaby, from his perch on the armchair, observed the newcomer with icy disdain. It had oversized ears, wobbled when it walked, and its mewl was a high-pitched offense to his dignified ears.
#
# For days, Barnaby maintained a policy of aloof avoidance. Pip, however, had no such reservations. The kitten saw the magnificent ginger cat not as a sovereign to be respected, but as a fascinating, tail-possessing mountain to be scaled. Pip would ambush Barnaby’s tail, pounce on his sleeping form, and attempt to nurse on his decidedly unfriendly fur.
#
# Barnaby would hiss, a sound like tearing velvet, and stalk away with his tail held like an offended exclamation mark. But the kitten was indefatigable.
#
# The turning point came during the afternoon bird-watch. Barnaby was in his usual position, a statue of concentration by the French doors, tracking the flitting sparrows. Pip, in a misguided attempt at camaraderie, launched himself at the glass, chirping a high-pitched kitten-war-cry. The sparrows scattered. Barnaby’s hunt was ruined.
#
# He turned, ready to deliver a hiss of such profound disapproval it would surely vaporize the tiny beast. But he stopped.
#
# Pip was sitting there, his little chest puffed out, looking immensely proud of himself. He looked up at Barnaby with wide, emerald-green eyes, not with fear or defiance, but with a pure, unadulterated admiration. He had, in his tiny mind, helped.
#
# Barnaby felt a strange sensation, an unfamiliar softening around the edges of his feline heart. He let out a sigh that ruffled his whiskers. Instead of hissing, he gave a low, rumbling mrrow? It wasn't a welcome, but it wasn't a rejection either.
#
# Pip, encouraged, took a tentative step forward. Then another. He bumped his tiny, cool nose against Barnaby’s larger, warm one. It was a gesture of trust, of kinship.
#
# Something unlocked in Barnaby’s stern soul. He remembered, in a foggy, distant way, being small. He remembered the terror of loud noises, the comfort of a larger, warmer body.
#
# That evening, a new routine began. Instead of occupying his solitary armchair, Barnaby settled onto the softest cushion on the sofa. Pip, after a moment’s hesitation, curled himself into a tiny ball in the curve of Barnaby’s generous ginger flank. Barnaby’s rumbling purr, a sound that had previously only been reserved for the opening of a tin of tuna, now vibrated through them both, a gentle engine of newfound contentment.
#
# Barnaby did not become a different cat. He was still the lord of the sunbeams, the guardian of the linens. But his domain now included a small, chaotic apprentice. He began to teach Pip the important things: how to track a sunbeam’s journey across the floor, the precise angle of head-tilt required to maximize a chin-scratch, the difference between a harmless housefly and a truly worthy moth.
#
# Pip, in turn, taught Barnaby about the joy of a randomly chased dust bunny and the sheer exhilaration of a mad, three-in-the-morning dash across the hallway.
#
# The humans would watch them, their hearts warming at the sight of the large, dignified cat patiently allowing the tiny kitten to bat at his tail, or the two of them sleeping in a single, intertwined puddle of fur.
#
# Barnaby had not lost his throne. He had simply gained a prince. And as the seasons turned and Pip grew into a sleek, graceful cat, their silent conversations continued—a language of blinked affection, synchronized naps, and the shared, profound understanding that the warmest spot in the world was always the one they found together.
#
# JOKE:
# Why don't cats play poker in the jungle?
#
# Because there are too many cheetahs.
#
# POEM:
# The velvet paw, the emerald eye,
# A silent shadow gliding by.
# A sunbeam stretched, a living sigh,
# A kingdom on the sill held high.
#
# No master owns the graceful form
# That rides the calm or weathers storm.
# A mystery in softest fur,
# A deeply resonant, rumbling purr.
#
# They deign to curl upon a lap,
# And grant a nap-time gentle tap.
# But in their dreams, what sights they see!
# Wild ancestors in jungles free.
#
# They chase the dust-motes in the light,
# A sudden, acrobatic flight.
# Then pause, with regal, cool disdain,
# And slowly close their eyes again.
#
# At night they hold a phantom court,
# On silent missions they resort.
# A miaow, a chirp, a trilling sound
# On their own secret, hallowed ground.
#
# So here's to cats, both great and small,
# Who grace our lives and rule the hall.
# A purring friend, a fickle soul,
# A universe beyond control.
